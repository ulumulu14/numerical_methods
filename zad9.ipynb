# %%
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %%
def fun(x):
    return 1 / (1 + 5 * x**2)

# %%
x_s = np.linspace(-1, 1, 65)
y_s = []

for x in x_s:
   y_s.append(fun(x))

# %%
spl = CubicSpline(x_s, y_s)

plt.figure(figsize = (14, 10))
plt.scatter(x_s, y_s)
plt.plot(x_s, spl(x_s), color = "darkred")
plt.show()
